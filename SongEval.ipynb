# %% [markdown]
# <a href="https://colab.research.google.com/github/SkinnyLadd/ASLP-SongEval/blob/main/SongEval.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
